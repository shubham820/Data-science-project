# %% [markdown]
# # pandas

# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '1.0.1'

# %%
dict_1 = {
    'age':[23,24,46],
    'city':['ludhiana','ludhiana','ludhiana'],
    'name':['shubham','sudesh','rubby']
}

# %%
df = pd.DataFrame(dict_1)

# %%
df
# Out:
#    age      city     name
# 0   23  ludhiana  shubham
# 1   24  ludhiana   sudesh
# 2   46  ludhiana    rubby

# %%
df.to_csv('family.csv',index = False)

# %%
df.head(1)
# Out:
#    age      city     name
# 0   23  ludhiana  shubham

# %%
df.tail(1)
# Out:
#    age      city   name
# 2   46  ludhiana  rubby

# %%
df.head()
# Out:
#    age      city     name
# 0   23  ludhiana  shubham
# 1   24  ludhiana   sudesh
# 2   46  ludhiana    rubby

# %%
df.describe()
# Out:
#         age
# count   3.0
# mean   31.0
# std    13.0
# min    23.0
# 25%    23.5
# 50%    24.0
# 75%    35.0
# max    46.0

# %%
df.index = ['a','b','c']

# %%
df
# Out:
#    age      city     name
# a   23  ludhiana  shubham
# b   24  ludhiana   sudesh
# c   46  ludhiana    rubby

# %%
df
# Out:
#    age      city     name
# a   23  ludhiana  shubham
# b   24  ludhiana   sudesh
# c   46  ludhiana    rubby

# %%
df.sort_index(axis = 0,ascending=False)
# Out:
#    age      city     name
# c   46  ludhiana    rubby
# b   24  ludhiana   sudesh
# a   23  ludhiana  shubham

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#       name      city  age
# a  shubham  ludhiana   23
# b   sudesh  ludhiana   24
# c    rubby  ludhiana   46

# %%
df.loc['a','age']=5

# %%
df
# Out:
#    age      city     name
# a    5  ludhiana  shubham
# b   24  ludhiana   sudesh
# c   46  ludhiana    rubby

# %%
df.drop(['age'],axis =1)
# Out:
#        city     name
# a  ludhiana  shubham
# b  ludhiana   sudesh
# c  ludhiana    rubby

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.head()
# Out:
#    age      city     name
# 0    5  ludhiana  shubham
# 1   24  ludhiana   sudesh
# 2   46  ludhiana    rubby

# %%
df['age'].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# Name: age, dtype: bool

# %%
housing = pd.read_csv('mydata.csv')

# %%
housing
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
housing.shape
# Out:
# (506, 14)

# %%
housing[['CRIM','NOX']]
# Out:
#         CRIM    NOX
# 0    0.00632  0.538
# 1    0.02731  0.469
# 2    0.02729  0.469
# 3    0.03237  0.458
# 4    0.06905  0.458
# ..       ...    ...
# 501  0.06263  0.573
# 502  0.04527  0.573
# 503  0.06076  0.573
# 504  0.10959  0.573
# 505  0.04741  0.573
#
# [506 rows x 2 columns]

# %%
df = a = np.array([[[[1,2,3],[1,2,3]],[[1,2,3],[1,2,3]]],[[[1,2,3],[1,2,3]],[[1,2,3],[1,2,3]]]])

# %%
df
# Out:
# array([[[[1, 2, 3],
#          [1, 2, 3]],
#
#         [[1, 2, 3],
#          [1, 2, 3]]],
#
#
#        [[[1, 2, 3],
#          [1, 2, 3]],
#
#         [[1, 2, 3],
#          [1, 2, 3]]]])

# %%
df1 = pd.DataFrame(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-db4415aaf6fb> in <module>
# ----> 1 df1 = pd.DataFrame(df)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     462                 mgr = init_dict({data.name: data}, index, columns, dtype=dtype)
#     463             else:
# --> 464                 mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     465
#     466         # For data is list-like, or Iterable (will consume into list)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_ndarray(values, index, columns, dtype, copy)
#     167     # by definition an array here
#     168     # the dtypes will be coerced to a single dtype
# --> 169     values = prep_ndarray(values, copy=copy)
#     170
#     171     if dtype is not None:
# ...

# %%
housing = pd.read_csv('mydata.csv',nrows = 10)

# %%
housing
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# ...

# %%
housing
# Out:
#         CRIM  INDUS
# 0    0.00632   2.31
# 1    0.02731   7.07
# 2    0.02729   7.07
# 3    0.03237   2.18
# 4    0.06905   2.18
# ..       ...    ...
# 501  0.06263  11.93
# 502  0.04527  11.93
# 503  0.06076  11.93
# 504  0.10959  11.93
# 505  0.04741  11.93
#
# [506 rows x 2 columns]

# %%
housing.replace()
# Out:
#         CRIM  INDUS
# 0    0.00632   2.31
# 1    0.02731   7.07
# 2    0.02729   7.07
# 3    0.03237   2.18
# 4    0.06905   2.18
# ..       ...    ...
# 501  0.06263  11.93
# 502  0.04527  11.93
# 503  0.06076  11.93
# 504  0.10959  11.93
# 505  0.04741  11.93
#
# [506 rows x 2 columns]

# %%
housing = pd.read_csv('mydata.csv')

# %%
housing.replace()
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

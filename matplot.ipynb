# %% [markdown]
# # matplotlib

# %%
import matplotlib.pyplot as pl

# %%
import numpy as np

# %%
a = list(range(1,5))

# %%
a
# Out:
# [1, 2, 3, 4]

# %%
d = [2,3,4,5]

# %%
d
# Out:
# [2, 3, 4, 5]

# %%
pl.plot(a,d, color = 'c',marker='o',markersize='15',linestyle ='--',linewidth ='3')
pl.title('learning matplotlib',fontsize =20)
pl.xlabel('x label',fontsize =20)
pl.ylabel('do the working',fontsize =20)
pl.legend(['hello'],loc = 4)

# %%
from matplotlib import style

# %%
from matplotlib import style

# %%
from matplotlib import style

# %%
from matplotlib import style

# %%
f = [5,4,3,4]
style.use('ggplot')
pl.plot(a,d,label ="hello", color = 'c',marker='o',markersize='15',linestyle ='--',linewidth ='3')
pl.plot(a,f,label ="bye", color = 'g',marker='o',markersize='15',linestyle =':',linewidth ='3')
pl.title('learning matplotlib',fontsize =20)
pl.xlabel('x label',fontsize =20)
pl.ylabel('do the working',fontsize =20)
pl.legend(loc = 3)

# %%
f = [5,4,3,4]
pl.bar(a,d,label ="hello", color = 'c',linestyle ='--',linewidth ='3')
pl.bar(a,f,label ="bye", color = 'g',linestyle =':',linewidth ='3')
pl.title('learning matplotlib',fontsize =20)
pl.xlabel('x label',fontsize =20)
pl.ylabel('do the working',fontsize =20)
pl.legend(loc = 0)

# %%
ml_student_age = np.random.randint(1,101,100)

# %%
pl.hist(ml_student_age)
# Out:
# (array([ 6., 15.,  8., 11.,  9., 14., 10.,  5.,  9., 13.]),
#  array([ 1. , 10.6, 20.2, 29.8, 39.4, 49. , 58.6, 68.2, 77.8, 87.4, 97. ]),
#  <a list of 10 Patch objects>)

# %%
list_2 = []
